# %%
# Some code is shamelessly copied from Learning Blogs
# %matplotlib inline
import numpy as np
import pandas as pd
from pandas import Series
from pandas import DataFrame
from pandas import concat
from statsmodels.tsa.arima_model import ARIMA
from statsmodels.tsa.seasonal import seasonal_decompose
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.ensemble import RandomForestRegressor
from math import sqrt
import matplotlib.pyplot as plt
from sklearn.svm import SVR
from pylab import rcParams
import math
import zipfile
from datetime import datetime
from dateutil import parser
import datetime
import random

pd.set_option('display.max_columns', None)
rcParams['figure.figsize'] = 15, 5


def parseDate(d):
    try:
        return parser.parse(d)        
    except:
        return None

def maxD(v):
    dt1 = parseDate(v[0])
    dt2 = parseDate(v[1])
    if dt1 is not None and dt2 is not None:
        return max(dt1, dt2)
    elif dt1 is not None:
        return dt1
    else:
        return dt2
    
def addDelta(v):
    delta = datetime.timedelta(0,random.randint(1, 15), random.randint(1, 1001))
    dt = parseDate(str(v[0]))
    if dt is not None:
        return dt+delta
    else:
        return dt
    

    
def num(s):
    try:
        return int(s[0])
    except ValueError:
        return float(s[0])
    except ValueError:
        return None

def differ(v):
    d1 = num(v[0])
    d2 = num(v[1])
    if d1 is not None and d2 is not None and abs(d1-d2)<=10:
        return False
    else:
        return True
    
def pererr(err, avg):
    return (err/avg)*100

def mean(l):
    return reduce(lambda x, y: x + y, l) / len(l)

# create a differenced series
def difference(dataset, interval=1):
    diff = list()
    for i in range(interval, len(dataset)):
        value = dataset[i] - dataset[i - interval]
        diff.append(value)
    return np.array(diff)


# invert differenced value
def inverse_difference(history, pred, interval=1):
    return pred + history[-interval]

    
def predict(coef, history):
    pred = 0.0
    for i in range(1, len(coef)+1):
        pred += coef[i-1] * history[-i]
    return pred
# Out:
# /Library/Python/2.7/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
zf = zipfile.ZipFile('data/order-reports_09_10_2017_19_10.csv.zip') 
kp = pd.read_csv(zf.open('order-reports_09_10_2017_19_10.csv'), header=0)
# Out:
# /Library/Python/2.7/site-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (31,33,68,69,92,94,99,106,110,114,119,124,129,130,132,138) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
kpi=kp.iloc[:, 
          [0, 2, 6, 7, 8, 9, 10, 11, 14, 20, 22, 
           37, 38, 39, 75, 41, 93, 95]]
kpi.count()
# Out:
# Id                     12664
# Customer Name          12664
# From City              12664
# To City                12664
# Distance               12646
# From Sublocation       12664
# To Sublocation         12664
# Order Value             9915
# Used truck Type         9907
# Warehouse Start Loc    12664
# Warehouse End Loc      12664
# Sector Name            12664
# Tonnage                10546
# Per Ton Rate            5577
# Product Name           12664
# Freight Amount          9890
# Order Accepted          8716
# Order Blocked           2900
# dtype: int64

# %%
# Picking earliest of Order Accepted or Order Blocked date as Order Date
kpi['date']=kpi[['Order Accepted', 'Order Blocked']].apply(maxD, axis=1)
#kpi.drop(['Order Accepted', 'Order Blocked'], axis=1, inplace=True)
kpi.count()
# Out:
# /Library/Python/2.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# Id                     12664
# Customer Name          12664
# From City              12664
# To City                12664
# Distance               12646
# From Sublocation       12664
# To Sublocation         12664
# Order Value             9915
# Used truck Type         9907
# Warehouse Start Loc    12664
# Warehouse End Loc      12664
# Sector Name            12664
# Tonnage                10546
# Per Ton Rate            5577
# Product Name           12664
# Freight Amount          9890
# Order Accepted          8716
# Order Blocked           2900
# date                   11559
# dtype: int64

# %%
## Checking how much bad Values/Rows we have
kpi[(pd.isnull(kpi['Freight Amount'])==False) & (pd.isnull(kpi['Order Value'])==False)].count()
# Out:
# Id                     9890
# Customer Name          9890
# From City              9890
# To City                9890
# Distance               9877
# From Sublocation       9890
# To Sublocation         9890
# Order Value            9890
# Used truck Type        9890
# Warehouse Start Loc    9890
# Warehouse End Loc      9890
# Sector Name            9890
# Tonnage                9044
# Per Ton Rate           5577
# Product Name           9890
# Freight Amount         9890
# Order Accepted         7141
# Order Blocked          2800
# date                   9890
# dtype: int64

# %%
# droping all rows where we don't know about date (i.e date is null)
kpi = kpi[pd.isnull(kpi['date'])==False]
kpi.count()
# Out:
# Id                     11559
# Customer Name          11559
# From City              11559
# To City                11559
# Distance               11545
# From Sublocation       11559
# To Sublocation         11559
# Order Value             9915
# Used truck Type         9907
# Warehouse Start Loc    11559
# Warehouse End Loc      11559
# Sector Name            11559
# Tonnage                10545
# Per Ton Rate            5577
# Product Name           11559
# Freight Amount          9890
# Order Accepted          8716
# Order Blocked           2900
# date                   11559
# dtype: int64

# %%
# calculating per unit km per ton price for the lane
kpi['ptr'] = (kpi['Freight Amount']/(kpi['Tonnage']*(kpi['Distance']/1000)))

# %%
# check whether we have duplicate dates
kpi['date'].unique().size
# Out:
# 10344

# %%
kpi[kpi.date.duplicated()]
# Out:
#            Id                             Customer Name From City  \
# 176    348671                                   Vertigo    Mundra
# 346    365528                               Raghav Goel    Mundra
# 422    339086                               Raghav Goel    Mundra
# 514    190568                      Gandhidham Customers    Mundra
# 593    352760                                Sharp Corp    Mundra
# 598    357981                                Vipin Jain    Mundra
# 601    366170                                   Sarthak    Mundra
# 657    339815                                   Vertigo    Mundra
# 689    361177                               konkan agro    Mundra
# 725    357004                      Sachin Vikash Pulses    Mundra
# 730    365527                               Raghav Goel    Mundra
# 758    385861                       mukesh  chahat ent.    Mundra
# 785    206357              Philips Carbon Black Limited    Mundra
# 789    191912                      Gandhidham Customers    Mundra
# 790    191913                      Gandhidham Customers    Mundra
# 953    357305                               konkan agro    Mundra
# 970    348471                                   Vertigo    Mundra
# 971    346244                     Manoj&Company  Mumbai    Mundra
# 973    348882                                   Vertigo    Mundra
# 988    340397           Adani Enterprises (Mundra Port)    Mundra
# 1012   366943                        Harish Rasik leela    Mundra
# 1043   353641                                Sharp Corp    Mundra
# 1060   356282                                   Sarthak    Mundra
# 1072   348987                                   Sarthak    Mundra
# 1098   361344                                Deepak jha    Mundra
# 1108   367598                                Vipin Jain    Mundra
# 1122   384959                               Raghav Goel    Mundra
# 1130   382181                           RIFAKAT HUSAIN     Mundra
# 1143   143307                      Jai Sai Coal Traders    Mundra
# 1161   151127              Philips Carbon Black Limited    Mundra
# ...       ...                                       ...       ...
# 12561  381898                            Rakshit Bansal     Anjar
# 12562  382951                      SBC Minerals Pvt Ltd     Anjar
# 12563  382954                      SBC Minerals Pvt Ltd     Anjar
# 12614                   NaN 2017-10-07 12:28:00  2.612873
# 12616                   NaN 2017-10-08 10:14:00  2.425917
# 12617                   NaN 2017-10-08 10:36:00  2.035415
# 12620                   NaN 2017-09-18 11:10:00  2.538393
# 12623                   NaN 2017-09-24 15:21:00  2.457214
# 12636                   NaN 2017-10-09 16:06:00  2.183325
# 12637                   NaN 2017-10-09 16:11:00  2.782816
# 12639                   NaN 2017-09-29 15:47:00  2.221168
# 12641                   NaN 2017-10-02 18:21:00  2.374883
# 12643                   NaN 2017-09-29 10:08:00  2.134133
# 12654                   NaN 2017-10-08 12:07:00  2.827983
# 12661                   NaN 2017-10-02 13:14:00  2.037591
# 12662                   NaN 2017-09-24 13:24:00  2.435239
#
# [1215 rows x 20 columns]

# %%
# how many duplicates we have
kpi[kpi.date.duplicated()].count()
# Out:
# Id                     1215
# Customer Name          1215
# From City              1215
# To City                1215
# Distance               1215
# From Sublocation       1215
# To Sublocation         1215
# Order Value            1009
# Used truck Type        1009
# Warehouse Start Loc    1215
# Warehouse End Loc      1215
# Sector Name            1215
# Tonnage                1161
# Per Ton Rate            842
# Product Name           1215
# Freight Amount         1006
# Order Accepted         1166
# Order Blocked            51
# date                   1215
# ptr                     970
# dtype: int64

# %%
# Lets try to make d as unique as possible by adding some secs, ms
kpi['d'] = kpi[['date']].apply(addDelta, axis=1)

# %%
kpi['d'].unique().size
# should come around the count of rows we have
# Out:
# 11559

# %%
# Lets Group By by ('From City', 'From Sublocation', 'To City', 'To Sublocation', 'Used truck Type', 'Product Name')
kpi.groupby(['From City', 'From Sublocation', 'To City', 'To Sublocation', 'Used truck Type', 'Product Name']).count().nlargest(10, 'Id')
# Out:
#                                                                                          Id  \
# From City From Sublocation To City       To Sublocation Used truck Type Product Name
# Anjar     Kandla           Pune          Kurkumbh       21T/20T         Agriculture     419
#                            Pathankot     Pathankot      30 MT           Coal            364
#           Lilashah Nagar   Agra          Dholpur House  27T/28T         Packaged Foods  284
# Mundra    Mundra           New Delhi     Block A1       27T/28T         Agriculture     204
# Anjar     Kandla           Muzaffarnagar Muzaffarnagar  34T             Coal            203
#                            Pune          Kasba Peth     21T/20T         Agriculture     194
#           Lilashah Nagar   Agra          Dholpur House  27T/28T         Oil             176
#           Gandhidham       Panipat       Panipat        27T/28T         Textiles        175
#           Kandla           Ahmedabad     Narolgam       30 MT           Coal            171
#                            Vallabhnagar  Dabok          30 MT           Coal            154
#
#                                                                                         Customer Name  \
# From City From Sublocation To City       To Sublocation Used truck Type Product Name
# Anjar     Kandla           Pune          Kurkumbh       21T/20T         Agriculture               419
#                            Pathankot     Pathankot      30 MT           Coal                      364
#           Lilashah Nagar   Agra          Dholpur House  27T/28T         Packaged Foods            284
# Mundra    Mundra           New Delhi     Block A1       27T/28T         Agriculture               204
# Anjar     Kandla           Muzaffarnagar Muzaffarnagar  34T             Coal                      203
#                            Pune          Kasba Peth     21T/20T         Agriculture               194
#           Lilashah Nagar   Agra          Dholpur House  27T/28T         Oil                       176
#           Gandhidham       Panipat       Panipat        27T/28T         Textiles                  175
#
#                                                                                           d
# From City From Sublocation To City       To Sublocation Used truck Type Product Name
# Anjar     Kandla           Pune          Kurkumbh       21T/20T         Agriculture     419
#                            Pathankot     Pathankot      30 MT           Coal            364
#           Lilashah Nagar   Agra          Dholpur House  27T/28T         Packaged Foods  284
# Mundra    Mundra           New Delhi     Block A1       27T/28T         Agriculture     204
# Anjar     Kandla           Muzaffarnagar Muzaffarnagar  34T             Coal            203
#                            Pune          Kasba Peth     21T/20T         Agriculture     194
#           Lilashah Nagar   Agra          Dholpur House  27T/28T         Oil             176
#           Gandhidham       Panipat       Panipat        27T/28T         Textiles        175
#           Kandla           Ahmedabad     Narolgam       30 MT           Coal            171
#                            Vallabhnagar  Dabok          30 MT           Coal            154

# %%
kpi.groupby(['From City', 'Used truck Type']).count().nlargest(10, 'Id')
# Out:
#                              Id  Customer Name  To City  Distance  \
# From City Used truck Type
# Anjar     27T/28T          3516           3516     3516      3514
#           21T/20T          1861           1861     1861      1855
#           30 MT            1747           1747     1747      1746
#           34T               778            778      778       778
# Mundra    27T/28T           532            532      532       532
#           34T               437            437      437       437
#           30 MT             264            264      264       264
# Anjar     25T/24T           217            217      217       216
#           16T/15T           215            215      215       213
# Mundra    16T/15T           155            155      155       154
#
#                            From Sublocation  To Sublocation  Order Value  \
# From City Used truck Type
# Anjar     27T/28T                      3516            3516         3513
#           21T/20T                      1861            1861         1860
#           30 MT                        1747            1747         1747
#           34T                           778             778          778
# Mundra    27T/28T                       532             532          530
#           34T                           437             437          434
#           30 MT                         264             264          264
# Anjar     25T/24T                       217             217          217
#           16T/15T                       215             215          215
# Mundra    16T/15T                       155             155          155
#
#                            Warehouse Start Loc  Warehouse End Loc  \
# From City Used truck Type
# Anjar     27T/28T                         3516               3516
#           21T/20T                         1861               1861
#           30 MT                           1747               1747
#           34T                              778                778
# Mundra    27T/28T                          532                532
#           34T                              437                437
#           30 MT                            264                264
# Anjar     25T/24T                          217                217
#           16T/15T                          215                215
# Mundra    16T/15T                          155                155
#
#                            Sector Name  Tonnage  Per Ton Rate  Product Name  \
# From City Used truck Type
# Anjar     27T/28T                 3516     2924          2082          3516
#           21T/20T                 1861     1671           242          1861
#           30 MT                   1747     1746          1742          1747
#           34T                      778      738           658           778
# Mundra    27T/28T                  532      529           140           532
#           34T                      437      433           217           437
#           30 MT                    264      264           260           264
# Anjar     25T/24T                  217      186            75           217
#           16T/15T                  215      213             8           215
# Mundra    16T/15T                  155      155             0           155
#
#                            Freight Amount  Order Accepted  Order Blocked  \
# From City Used truck Type
# Anjar     27T/28T                    3512            2402           1129
#           21T/20T                    1854            1147            724
#           30 MT                      1747            1741             19
#           34T                         778             659            124
# Mundra    27T/28T                     530             138            395
#           34T                         434             216            222
#           30 MT                       264             260              5
# Anjar     25T/24T                     217             144             74
#           16T/15T                     214             145             71
# Mundra    16T/15T                     155             140             18
#
#                            date   ptr     d
# From City Used truck Type
# Anjar     27T/28T          3516  2922  3516
#           21T/20T          1861  1665  1861
#           30 MT            1747  1745  1747
#           34T               778   738   778
# Mundra    27T/28T           532   529   532
#           34T               437   433   437
#           30 MT             264   264   264
# Anjar     25T/24T           217   185   217
#           16T/15T           215   211   215
# Mundra    16T/15T           155   154   155

# %%
kpi.groupby(['From City', 'Product Name']).count().nlargest(10, 'Id')
# Out:
#                             Id  Customer Name  To City  Distance  \
# From City Product Name
# Anjar     Coal            3113           3113     3113      3111
#           Oil             2336           2336     2336      2336
#           Agriculture     2026           2026     2026      2017
#           Packaged Foods   904            904      904       904
# Mundra    Coal             739            739      739       739
# Anjar     Sugar            411            411      411       411
# Mundra    Agriculture      404            404      404       404
# Anjar     Textiles         241            241      241       241
#           Non-metals       219            219      219       219
# Mundra    Yellow Peas      218            218      218       218
#
#                           From Sublocation  To Sublocation  Order Value  \
# From City Product Name
# Anjar     Coal                        3113            3113         2455
#           Oil                         2336            2336         1910
#           Agriculture                 2026            2026         1964
#           Packaged Foods               904             904          882
# Mundra    Coal                         739             739          620
# Anjar     Sugar                        411             411          376
# Mundra    Agriculture                  404             404          400
# Anjar     Textiles                     241             241          191
#           Non-metals                   219             219          210
# Mundra    Yellow Peas                  218             218          164
#
#                           Used truck Type  Warehouse Start Loc  \
# From City Product Name
# Anjar     Coal                       2455                 3113
#           Oil                        1910                 2336
#           Agriculture                1954                 2026
#           Packaged Foods              879                  904
# Mundra    Coal                        623                  739
# Anjar     Sugar                       376                  411
# Mundra    Agriculture                 402                  404
# Anjar     Textiles                    193                  241
#           Non-metals                  209                  219
# Mundra    Yellow Peas                 164                  218
#
#                           Warehouse End Loc  Sector Name  Tonnage  \
# From City Product Name
# Anjar     Coal                         3113         3113     3103
#           Oil                          2336         2336     2336
#           Agriculture                  2026         2026     1947
#           Packaged Foods                904          904       33
# Mundra    Coal                          739          739      729
# Anjar     Sugar                         411          411      400
# Mundra    Agriculture                   404          404      400
# Anjar     Textiles                      241          241      236
#           Non-metals                    219          219      210
# Mundra    Yellow Peas                   218          218      218
#
#                           Per Ton Rate  Freight Amount  Order Accepted  \
# From City Product Name
# Anjar     Coal                    2250            2455            2895
#           Oil                     1910            1910            2336
#           Agriculture                5            1949             992
#           Packaged Foods             2             874             311
# Mundra    Coal                     390             620             500
# Anjar     Sugar                    264             376             288
# Mundra    Agriculture                1             400               0
# Anjar     Textiles                 134             191             180
#           Non-metals                 0             209             147
# Mundra    Yellow Peas              164             164             218
#
#                           Order Blocked  date   ptr     d
# From City Product Name
# Anjar     Coal                      233  3113  2452  3113
#           Oil                         7  2336  1910  2336
#           Agriculture              1052  2026  1939  2026
#           Packaged Foods            596   904    33   904
# Mundra    Coal                      241   739   618   739
# Anjar     Sugar                     125   411   376   411
# Mundra    Agriculture               404   404   400   404
# Anjar     Textiles                   62   241   191   241
#           Non-metals                 72   219   209   219
# Mundra    Yellow Peas                 1   218   164   218

# %%
# Group by From City
kpi.groupby(['From City']).count().nlargest(10, 'Id')
# Out:
#              Id  Customer Name  To City  Distance  From Sublocation  \
# From City
# Anjar      9882           9882     9882      9869              9882
# Mundra     1677           1677     1677      1676              1677
#
#            To Sublocation  Order Value  Used truck Type  Warehouse Start Loc  \
# From City
# Anjar                9882         8471             8458                 9882
# Mundra               1677         1444             1449                 1677
#
#            Warehouse End Loc  Sector Name  Tonnage  Per Ton Rate  \
# From City
# Anjar                   9882         9882     8886          4931
# Mundra                  1677         1677     1659           646
#
#            Product Name  Freight Amount  Order Accepted  Order Blocked  date  \
# From City
# Anjar              9882            8446            7709           2224  9882
# Mundra             1677            1444            1007            676  1677
#
#             ptr     d
# From City
# Anjar      7590  9882
# Mundra     1441  1677

# %%
# Let's work out on Top 3 lane based on count of orders
s1 = kpi[(kpi['From Sublocation']=='Tuna') & (kpi['To Sublocation']=='Pathankot') & (kpi['Used truck Type']=='30 MT') & (kpi['Product Name']=='Coal')]
s2 = kpi[(kpi['From Sublocation']=='Kandla') & (kpi['To Sublocation']=='Dabok') & (kpi['Used truck Type']=='30 MT') & (kpi['Product Name']=='Coal')]
s3 = kpi[(kpi['From Sublocation']=='Kandla') & (kpi['To Sublocation']=='Dholka') & (kpi['Used truck Type']=='30 MT') & (kpi['Product Name']=='Coal')]
# We are droping Anjar-Agra as there is no info about Tonnage, we will see it later on
s4 = kpi[(kpi['From Sublocation']=='Lilashah Nagar') & (kpi['To Sublocation']=='Dholpur House') & (kpi['Used truck Type']=='27T/28T') & (kpi['Product Name']=='Packaged Foods')]

# %%
# per km per ton price for the shorter lane is higher than longer lanes 
# that may be inferred due to fixed cost of driver
s = [s1, s2, s3]
sp = [Series(x['ptr'].values, index=x['d']) for x in s]
[x.plot() for x in sp]
# Out:
# [<matplotlib.axes._subplots.AxesSubplot at 0x10ed45f10>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x10ed45f10>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x10ed45f10>]

# %%
s = [s1, s2, s3, s4]
s = [Series(x['Per Ton Rate'].values, index=x['d']) for x in s]

# %%
s4
# Out:
#            Id        Customer Name From City To City   Distance  \
# 2804   214086  Bunge India Pvt Ltd     Anjar    Agra  1079957.0
# 2805   212852  Bunge India Pvt Ltd     Anjar    Agra  1079957.0
# 2810   212032  Bunge India Pvt Ltd     Anjar    Agra  1078056.0
# 2821   271924  Bunge India Pvt Ltd     Anjar    Agra  1079695.0
# 2823   278680  Bunge India Pvt Ltd     Anjar    Agra  1079695.0
# 2827   282364  Bunge India Pvt Ltd     Anjar    Agra  1079696.0
# 2828   279329  Bunge India Pvt Ltd     Anjar    Agra  1079695.0
# 2830   275272  Bunge India Pvt Ltd     Anjar    Agra  1079695.0
# 2831   282470  Bunge India Pvt Ltd     Anjar    Agra  1081206.0
# 2832   272710  Bunge India Pvt Ltd     Anjar    Agra  1079695.0
# 2833   274347  Bunge India Pvt Ltd     Anjar    Agra  1081206.0
# 2834   276421  Bunge India Pvt Ltd     Anjar    Agra  1079695.0
# 2835   282072  Bunge India Pvt Ltd     Anjar    Agra  1079696.0
# 2836   275791  Bunge India Pvt Ltd     Anjar    Agra  1079695.0
# 2838   277628  Bunge India Pvt Ltd     Anjar    Agra  1081206.0
# 2840   278734  Bunge India Pvt Ltd     Anjar    Agra  1079695.0
# 2842   279327  Bunge India Pvt Ltd     Anjar    Agra  1079695.0
# 2843   279328  Bunge India Pvt Ltd     Anjar    Agra  1079695.0
# 10980 2017-05-29 12:58:11.000329
# 10981 2017-05-18 18:57:06.000542
# 10982 2017-05-17 12:58:04.000507
# 10983 2017-05-24 12:35:01.000789
# 10984 2017-05-25 10:03:03.000617
# 10985 2017-05-25 10:48:06.000199
# 10986 2017-05-27 17:47:15.000161
# 10994 2017-05-23 14:53:14.000212
# 10995 2017-05-18 21:09:07.000444
# 10996 2017-05-18 18:22:13.000053
# 10997 2017-05-18 18:30:02.000939
# 10998 2017-05-27 16:27:13.000444
#
# [284 rows x 21 columns]

# %%
# run RF takes a pandas.Series with dateIndex and T as number of Test Points
def runRF(series, T, W):
    X = series.values
    size = len(X) - T

    # move each window by 1 data point
    # keep last chunk for prediction
    NWs = len(X)-W-T-1 

    # Features should have dimensions (NWs x WSize)
    # Labels should have dimensions (NWs)
    feat = np.zeros( [NWs, W] ) - 9999999. # blank array to fill
    labl = np.zeros( [NWs] ) - 99999.
    sh = np.shape(feat)
    
    # Now fill the feature and label arrays with differencing
    for i in range(int(NWs)):
        feat[i,:] = X[i:i+W] - X[i+W]
        labl[i] = X[i+W+1] - X[i+W]
        
    
    # Now make test features and test labels to compare with
    test_feat = np.zeros( [T, W] )
    test_labl = np.zeros( [T] )

    for i in range(T):
        test_feat[i,:] = X[i+NWs:i+NWs+W] - X[i+NWs+W]
        test_labl[i] = X[i+NWs+W+1] - X[i+NWs+W]
    
    # Code taken from Josh Bloom's lecture
    from sklearn.ensemble import RandomForestRegressor
    rfRegress = RandomForestRegressor(n_estimators=500, 
                                criterion='mae', max_depth=None, 
                                min_samples_split=2, min_samples_leaf=1, 
                                max_features='auto', max_leaf_nodes=None, 
                                bootstrap=True, oob_score=False, n_jobs=1, 
                                random_state=None, verbose=0)
    rfRegress.fit(feat, labl)
    pred = rfRegress.predict(test_feat)
    #plt.plot(test_labl, "b-")
    #plt.plot(pred,'go')

    
    #Series(pred, series.index[size:]).plot(color="green", label="Prediction_DIFF")
    #Series(test_labl, series.index[size:]).plot(color="blue", label="Expected_DIFF_Smoothed") 
    
    
    ### Lets get some numbers
    test_labl_act = np.zeros( [T] )
    pred_act = np.zeros( [T] )
    errs = []
    for i in range(T):
        test_labl_act[i] = test_labl[i] + X[i+NWs+W]
        pred_act[i] = pred[i] + X[i+NWs+W]
        err=pererr(abs(test_labl_act[i]-pred_act[i]),test_labl_act[i])
        errs.append(err)
    rmse = sqrt(mean_squared_error(pred_act, test_labl_act))
    mae = mean_absolute_error(pred_act, test_labl_act)
    print('Test RMSE: %.3f, MAE:%.3f, Err:%.3f'% (rmse, mae, mean(errs)))
    acts =Series(test_labl_act, series.index[size:])
    preds=Series(pred_act, series.index[size:])
    preds.plot(color="red", label="Prediction")
    acts.plot(color="blue", label="Expected_Smoothed") 
    #plt.plot(test_labl_act, "o-")
    #plt.plot(pred_act,'r+')
    return pred_act

# %%
# lets try to run some models now
# Let's resample series into 1day bucket and filling missing values by mean
s_fna = [x.resample("1d").mean().fillna(method="ffill") for x in s]
s_len = [len(x) for x in s]
s_len
# Out:
# [364, 154, 114, 284]

# %%
l = len(s_fna[0])
t = 40
w = 7
pred = runRF(s_fna[0], t, w)
plt.legend()
# Out:
# Test RMSE: 47.302, MAE:34.622, Err:1.303

# %%
Series(pred).plot(label="predicted")
Series(s_fna[0].values[-t:]).plot(label="Actual_Smoothed")
plt.legend()

# %%
l = len(s_fna[1])
print l
t = 12
w = 3
pred = runRF(s_fna[1], t, w)
# Out:
# 59
# Test RMSE: 0.000, MAE:0.000, Err:0.000

# %%
Series(pred).plot()
Series(s_fna[1].values[-t:]).plot()

# %%
l = len(s_fna[2])
print l
t = 35
w = 7
pred = runRF(s_fna[2], t, w)
# Out:
# 50
# Test RMSE: 12.189, MAE:4.000, Err:0.522

# %%
Series(pred).plot()
Series(s_fna[2].values[-t:]).plot()

# %%
s1.groupby("Customer Name").count()
# Out:
#                            Id  From City  To City  Distance  From Sublocation  \
# Customer Name
# Anil Pichi Srinagar coal   49         49       49        49                49
# Balwinder                  69         69       69        69                69
# Deepak jha                 10         10       10        10                10
# Dheeraj                     4          4        4         4                 4
# Jai Sai Coal Traders       26         26       26        26                26
# Jaidev Singh                4          4        4         4                 4
# Joshi                       1          1        1         1                 1
# KP Coal Traders             2          2        2         2                 2
# Mahalaxmi Sachin            8          8        8         8                 8
# Piyush Coal Sales           2          2        2         2                 2
# ROHIT sihag                 1          1        1         1                 1
# Rohit                       1          1        1         1                 1
# balwindar                  18         18       18        18                18
# konkan agro               167        167      167       167               167
# sachin gupta                2          2        2         2                 2
#
#                           To Sublocation  Order Value  Used truck Type  \
# Customer Name
# Anil Pichi Srinagar coal              49           49               49
# Balwinder                             69           69               69
# Deepak jha                            10           10               10
# Dheeraj                                4            4                4
# Jai Sai Coal Traders                  26           26               26
# Jaidev Singh                           4            4                4
# Joshi                                  1            1                1
# KP Coal Traders                        2            2                2
# Mahalaxmi Sachin                       8            8                8
# Piyush Coal Sales                      2            2                2
# ROHIT sihag                            1            1                1
# Rohit                                  1            1                1
# balwindar                             18           18               18
# konkan agro                          167          167              167
# sachin gupta                           2            2                2
#
#                           Warehouse Start Loc  Warehouse End Loc  Sector Name  \
# Customer Name
# Anil Pichi Srinagar coal                   49                 49           49
# Balwinder                                  69                 69           69
# Deepak jha                                 10                 10           10
# Dheeraj                                     4                  4            4
# Jai Sai Coal Traders                       26                 26           26
# Jaidev Singh                                4                  4            4
# Joshi                                       1                  1            1
# KP Coal Traders                             2                  2            2
# Mahalaxmi Sachin                            8                  8            8
# Piyush Coal Sales                           2                  2            2
# ROHIT sihag                                 1                  1            1
# Rohit                                       1                  1            1
# balwindar                                  18                 18           18
# konkan agro                               167                167          167
# sachin gupta                                2                  2            2
#
#                           Tonnage  Per Ton Rate  Product Name  Freight Amount  \
# Customer Name
# Anil Pichi Srinagar coal       49            49            49              49
# Balwinder                      69            69            69              69
# Deepak jha                     10            10            10              10
# Dheeraj                         4             4             4               4
# Jai Sai Coal Traders           26            26            26              26
# Jaidev Singh                    4             4             4               4
# Joshi                           1             1             1               1
# KP Coal Traders                 2             2             2               2
# Mahalaxmi Sachin                8             8             8               8
# Piyush Coal Sales               2             2             2               2
# ROHIT sihag                     1             1             1               1
# Rohit                           1             1             1               1
# balwindar                      18            18            18              18
# konkan agro                   167           167           167             167
# sachin gupta                    2             2             2               2
#
#                           Order Accepted  Order Blocked  date  ptr    d
# Customer Name
# Anil Pichi Srinagar coal              49              0    49   49   49
# Balwinder                             69              0    69   69   69
# Deepak jha                            10              0    10   10   10
# Dheeraj                                4              0     4    4    4
# Jai Sai Coal Traders                  26              1    26   26   26
# Jaidev Singh                           4              0     4    4    4
# Joshi                                  1              0     1    1    1
# KP Coal Traders                        2              0     2    2    2
# Mahalaxmi Sachin                       8              0     8    8    8
# Piyush Coal Sales                      2              0     2    2    2
# ROHIT sihag                            1              0     1    1    1
# Rohit                                  1              0     1    1    1
# balwindar                             18              0    18   18   18
# konkan agro                          167              0   167  167  167
# sachin gupta                           2              0     2    2    2

# %%
ka=s1[s1['Customer Name']=='konkan agro']
ap=s1[s1['Customer Name']=='Anil Pichi Srinagar coal']
bw=s1[s1['Customer Name']=='Balwinder']
bw2=s1[s1['Customer Name']=='balwindar']
cs = [ka, ap, bw, bw2]

# %%
csp = [Series(x['ptr'].values, index=x['d']) for x in cs]
[x.plot() for x in csp]
# Out:
# [<matplotlib.axes._subplots.AxesSubplot at 0x117d3d4d0>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x117d3d4d0>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x117d3d4d0>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x117d3d4d0>]

# %%
csp = [Series(x['Per Ton Rate'].values, index=x['d']) for x in cs]
[x.plot() for x in csp]
# Out:
# [<matplotlib.axes._subplots.AxesSubplot at 0x117912c10>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x117912c10>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x117912c10>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x117912c10>]

# %%
# lets try to run some models now -- FOR PTR
# Let's resample series into 1day bucket and filling missing values by mean
s_fna = [x.resample("1d").mean().fillna(method="ffill") for x in sp]
s_len = [len(x) for x in s]
s_len
# Out:
# [364, 154, 114, 284]

# %%
l = len(s_fna[0])
t = 40
w = 7
pred = runRF(s_fna[0], t, w)
# Out:
# Test RMSE: 0.029, MAE:0.021, Err:1.134

# %%
Series(pred).plot()
Series(s_fna[0].values[-t:]).plot()

# %%
# Let's Try out Anjar-Agra for Freight Amount prediction
s4.count()
# Out:
# Id                     284
# Customer Name          284
# From City              284
# To City                284
# Distance               284
# From Sublocation       284
# To Sublocation         284
# Order Value            283
# Used truck Type        284
# Warehouse Start Loc    284
# Warehouse End Loc      284
# Sector Name            284
# Tonnage                  0
# Per Ton Rate             0
# Product Name           284
# Freight Amount         282
# Order Accepted          77
# Order Blocked          208
# date                   284
# ptr                      0
# d                      284
# dtype: int64

# %%
x = s4
s4t = Series(x['Freight Amount'].values, index=x['d'])
s4t.plot()

# %%
s4_1d_fna = s4t.resample("1d").mean().fillna(method="ffill")
s4_1d_fna.plot()

# %%
l = len(s4_1d_fna)
print l
t = 40
w = 7
pred = runRF(s4_1d_fna, t, w)
# Out:
# 149
# Test RMSE: 1807.168, MAE:1365.676, Err:1.858

# %%
s=s1[s1['date']>"06/01/2017"]
series = Series(s['Per Ton Rate'].values, index=s['date'])
series.sort_index()
series.resample("1d").mean().fillna(method="ffill").plot()

# %%
series.sort_index()
# Out:
# 2820.0
